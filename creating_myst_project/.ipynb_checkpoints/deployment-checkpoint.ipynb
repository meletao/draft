# %% [markdown]
# # Deployment
#
# To host the content on github pages. Run:
# ```
# myst init --gh-pages
# ```
#
# This creates a directory `.github` with a `deploy.yml` file which contains the workflow to host it on github pages trigerred automatically when push the code to the remote repository.
#
# You need to ensure that the repository allows to run github action for deployment.
